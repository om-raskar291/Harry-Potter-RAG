# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
#from langchain_huggingface import HuggingFaceEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
import os
import time
import warnings
warnings.filterwarnings('ignore')

print("All imports done!")
# Out:
# All imports done!

# %%
import os
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.vectorstores import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
import gradio as gr

# Set your Gemini API Key
# (Get your API key from Google AI Studio: https://aistudio.google.com/)
os.environ['GOOGLE_API_KEY'] = "YOUR_GOOGLE_GEMINI_API_KEY_HERE"

# %%
# !pip install --upgrade --force-reinstall cffi cryptography
# Out:
# Collecting cffi
#   Downloading cffi-2.1.1-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting cryptography
#   Downloading cryptography-50.0.0-cp311-abi3-win_amd64.whl.metadata (4.3 kB)
# Collecting pycparser (from cffi)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading cffi-2.1.1-cp313-cp313-win_amd64.whl (185 kB)
# Downloading cryptography-50.0.0-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 887.2 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.5/3.8 MB 887.2 kB/s eta 0:00:04
#    -------- ------------------------------- 0.8/3.8 MB 607.8 kB/s eta 0:00:06
#    ---------- ----------------------------- 1.0/3.8 MB 679.4 kB/s eta 0:00:05
#    ---------------- ----------------------- 1.6/3.8 MB 869.3 kB/s eta 0:00:03
#    ------------------- -------------------- 1.8/3.8 MB 841.3 kB/s eta 0:00:03
#    --------------------- ------------------ 2.1/3.8 MB 779.8 kB/s eta 0:00:03
#    ------------------------ --------------- 2.4/3.8 MB 757.7 kB/s eta 0:00:02
#    --------------------------- ------------ 2.6/3.8 MB 759.8 kB/s eta 0:00:02
#    ------------------------------ --------- 2.9/3.8 MB 752.3 kB/s eta 0:00:02
#    -------------------------------- ------- 3.1/3.8 MB 744.5 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 558.2 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 558.2 kB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 460.1 kB/s  0:00:07
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: pycparser, cffi, cryptography
#
#   Attempting uninstall: pycparser
#
#    ---------------------------------------- 0/3 [pycparser]
#     Found existing installation: pycparser 2.23
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#     Uninstalling pycparser-2.23:
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#       Successfully uninstalled pycparser-2.23
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#    ---------------------------------------- 0/3 [pycparser]
#   Attempting uninstall: cffi
#    ---------------------------------------- 0/3 [pycparser]
#    ------------- -------------------------- 1/3 [cffi]
#     Found existing installation: cffi 2.0.0
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#     Uninstalling cffi-2.0.0:
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#       Successfully uninstalled cffi-2.0.0
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#    ------------- -------------------------- 1/3 [cffi]
#   Attempting uninstall: cryptography
#    ------------- -------------------------- 1/3 [cffi]
#    -------------------------- ------------- 2/3 [cryptography]
#     Found existing installation: cryptography 50.0.0
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#     Uninstalling cryptography-50.0.0:
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#       Successfully uninstalled cryptography-50.0.0
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    -------------------------- ------------- 2/3 [cryptography]
#    ---------------------------------------- 3/3 [cryptography]
#
# Successfully installed cffi-2.1.1 cryptography-50.0.0 pycparser-3.0
# WARNING: Ignoring invalid distribution ~angchain-core (F:\Python_Files2026\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~radio (F:\Python_Files2026\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'F:\Python_Files2026\Lib\site-packages\~ryptography'.
#   You can safely remove it manually.

# %%
print("Hello")
# Out:
# Hello

# %%
pip install -qU langchain langchain-community langchain-text-splitters langchain-google-genai langchain-chroma chromadb gradio
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_google_genai import (
    GoogleGenerativeAIEmbeddings,
    ChatGoogleGenerativeAI
)

from langchain_chroma import Chroma

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

import os
# Out:
# C:\Users\om020\AppData\Local\Temp\ipykernel_12764\3460232825.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
from getpass import getpass
import os

GOOGLE_API_KEY = getpass("Enter your Google API Key: ")

os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
# Out:
# Enter your Google API Key:  ········

# %%
GOOGLE_API_KEY
# Out:
# 'AQ.Ab8RN6JCZpk56kBmJIj5EAhYGzYOjcSJNrY9QiDnl7scsev4pg'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

test_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

response = test_llm.invoke("Say hello in one sentence.")

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File F:\Python_Files2026\Lib\site-packages\langchain_google_genai\chat_models.py:3389, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3388 try:
# -> 3389     response: GenerateContentResponse = self.client.models.generate_content(
#    3390         **request,
#    3391     )
#    3392 except ClientError as e:
#
# File F:\Python_Files2026\Lib\site-packages\google\genai\models.py:6604, in Models.generate_content(self, model, contents, config)
#    6603 i += 1
# -> 6604 response = self._generate_content(
#    6605     model=model, contents=contents, config=parsed_config_to_call
#    6606 )
#    6608 if not function_map:
#
# File F:\Python_Files2026\Lib\site-packages\google\genai\models.py:5028, in Models._generate_content(self, model, contents, config)
#    5026 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5028 response = self._api_client.request(
#    5029     'post', path, request_dict, http_options
#    5030 )
#    5032 if config is not None and getattr(
#    5033     config, 'should_return_http_response', None
#    5034 ):
#
# File F:\Python_Files2026\Lib\site-packages\google\genai\_api_client.py:1708, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1705 http_request = self._build_request(
#    1706     http_method, path, request_dict, http_options
#    1707 )
# -> 1708 response = self._request(http_request, http_options, stream=False)
#    1709 response_body = (
#    1710     response.response_stream[0] if response.response_stream else ''
#    1711 )
#
# File F:\Python_Files2026\Lib\site-packages\google\genai\_api_client.py:1493, in BaseApiClient._request(self, http_request, http_options, stream)
#    1492     retry = tenacity.Retrying(**retry_kwargs)
# -> 1493     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1495 return self._retry(self._request_once, http_request, stream)
#
# File F:\Python_Files2026\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File F:\Python_Files2026\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File F:\Python_Files2026\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File F:\Python_Files2026\Lib\concurrent\futures\_base.py:453, in Future.result(self, timeout)
#     452 elif self._state == FINISHED:
# --> 453     return self.__get_result()
#     455 self._condition.wait(timeout)
#
# File F:\Python_Files2026\Lib\concurrent\futures\_base.py:402, in Future.__get_result(self)
#     401 try:
# --> 402     raise self._exception
#     403 finally:
#     404     # Break a reference cycle with the exception in self._exception
#
# File F:\Python_Files2026\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File F:\Python_Files2026\Lib\site-packages\google\genai\_api_client.py:1472, in BaseApiClient._request_once(self, http_request, stream)
#    1471   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1472 errors.APIError.raise_for_response(response)
#    1473 return HttpResponse(
#    1474     response.headers, response if stream else [response.text]
#    1475 )
#
# File F:\Python_Files2026\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File F:\Python_Files2026\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'This model models/gemini-2.5-flash is no longer available to new users. Please update your code to use a newer model for the latest features and improvements. We recommend you to use the Interactions API (https://ai.google.dev/gemini-api/docs/migrate-to-interactions).', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[6], line 8
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
#       3 test_llm = ChatGoogleGenerativeAI(
#       4     model="gemini-2.5-flash",
#       5     temperature=0
#       6 )
# ----> 8 response = test_llm.invoke("Say hello in one sentence.")
#      10 print(response.content)
#
# File F:\Python_Files2026\Lib\site-packages\langchain_google_genai\chat_models.py:2791, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2788         msg = "Tools are already defined.code_execution tool can't be defined"
#    2789         raise ValueError(msg)
# -> 2791 return super().invoke(input, config, stop=stop, **kwargs)
#
# File F:\Python_Files2026\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File F:\Python_Files2026\Lib\site-packages\langchain_core\language_models\chat_models.py:1865, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1856 @override
#    1857 def generate_prompt(
#    1858     self,
#    (...)   1862     **kwargs: Any,
#    1863 ) -> LLMResult:
#    1864     prompt_messages = [p.to_messages() for p in prompts]
# -> 1865     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File F:\Python_Files2026\Lib\site-packages\langchain_core\language_models\chat_models.py:1672, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1669 for i, m in enumerate(input_messages):
#    1670     try:
#    1671         results.append(
# -> 1672             self._generate_with_cache(
#    1673                 m,
#    1674                 stop=stop,
#    1675                 run_manager=run_managers[i] if run_managers else None,
#    1676                 **kwargs,
#    1677             )
#    1678         )
#    1679     except BaseException as e:
#    1680         if run_managers:
#
# File F:\Python_Files2026\Lib\site-packages\langchain_core\language_models\chat_models.py:2010, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2008     result = generate_from_stream(iter(chunks))
#    2009 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2010     result = self._generate(
#    2011         messages, stop=stop, run_manager=run_manager, **kwargs
#    2012     )
#    2013 else:
#    2014     result = self._generate(messages, stop=stop, **kwargs)
#
# File F:\Python_Files2026\Lib\site-packages\langchain_google_genai\chat_models.py:3393, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3389     response: GenerateContentResponse = self.client.models.generate_content(
#    3390         **request,
#    3391     )
#    3392 except ClientError as e:
# -> 3393     _handle_client_error(e, request)
#    3395 return _response_to_result(response)
#
# File F:\Python_Files2026\Lib\site-packages\langchain_google_genai\chat_models.py:177, in _handle_client_error(e, request)
#     175 model_name = request.get("model", "unknown")
#     176 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 177 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'This model models/gemini-2.5-flash is no longer available to new users. Please update your code to use a newer model for the latest features and improvements. We recommend you to use the Interactions API (https://ai.google.dev/gemini-api/docs/migrate-to-interactions).', 'status': 'NOT_FOUND'}}

# %%
from google import genai
import os

client = genai.Client(
    api_key=os.environ["GOOGLE_API_KEY"]
)

models = client.models.list()

for model in models:
    supported = getattr(model, "supported_actions", [])

    if "generateContent" in supported:
        print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemini-3.7-flash-video-understanding-eap
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-3.6-flash
# models/gemini-3.7-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-robotics-er-2-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

test_llm = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash",
    temperature=0
)

response = test_llm.invoke(
    "Say hello in one sentence."
)

print(response.content)
# Out:
# [{'type': 'text', 'text': 'Hello, how can I help you today?', 'extras': {'signature': '...'}}]

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(
    model="gemini-embedding-2"
)

test_embedding = embeddings.embed_query(
    "Who is Harry Potter?"
)

print("Embedding generated successfully.")
print("Embedding dimensions:", len(test_embedding))
print("First 10 values:", test_embedding[:10])
# Out:
# Embedding generated successfully.
# Embedding dimensions: 3072
# First 10 values: [0.011348297, 0.03477306, 0.018061483, -0.019972349, 0.008695679, -0.018019227, -0.010890927, 0.010897345, 0.015121684, -0.045104057]

# %%
splits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 splits
#
# NameError: name 'splits' is not defined

# %%
from langchain_chroma import Chroma

vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=embeddings,
    collection_name="harry_potter_rag"
)

print("Chroma Vector Store created successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 from langchain_chroma import Chroma
#       3 vectorstore = Chroma.from_documents(
# ----> 4     documents=splits,
#       5     embedding=embeddings,
#       6     collection_name="harry_potter_rag"
#       7 )
#       9 print("Chroma Vector Store created successfully.")
#
# NameError: name 'splits' is not defined

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
def load_and_split(filepath):

    loader = TextLoader(
        filepath,
        encoding="utf-8"
    )

    docs = loader.load()

    print("Splitting Data into Chunks")

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=500,
        chunk_overlap=50
    )

    splits = splitter.split_documents(docs)

    print(f"Split {len(splits)} chunks")

    return splits

# %%
#Jupyter_Book/2026 Python prac/08 August Py_ML/HarryPotterRag.tx
file_path = "HarryPotterRag.txt"

# %%
import os

print(os.path.exists(file_path))
# Out:
# True

# %%
splits = load_and_split(file_path)
# Out:
# Splitting Data into Chunks
# Split 4 chunks

# %%
print("Number of chunks:", len(splits))

print("\nFirst chunk:")
print(splits[0].page_content)

print("\nMetadata:")
print(splits[0].metadata)
# Out:
# Number of chunks: 4
#
# First chunk:
# Harry James Potter is a wizard and the central figure in the fight against the dark wizard Lord Voldemort. Harry was born on July 31, 1980, to James Potter and Lily Potter (née Evans).
#
# Metadata:
# {'source': 'HarryPotterRag.txt'}

# %%
print("Number of chunks:", len(splits))

print("\nFirst chunk:")
print(splits[0].page_content)

print("\nMetadata:")
print(splits[0].metadata)
# Out:
# Number of chunks: 4
#
# First chunk:
# Harry James Potter is a wizard and the central figure in the fight against the dark wizard Lord Voldemort. Harry was born on July 31, 1980, to James Potter and Lily Potter (née Evans).
#
# Metadata:
# {'source': 'HarryPotterRag.txt'}

# %%
from langchain_chroma import Chroma

vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=embeddings,
    collection_name="harry_potter_rag"
)

print("Chroma Vector Store created successfully.")
# Out:
# Chroma Vector Store created successfully.

# %%
retriever = vectorstore.as_retriever()

print("Retriever created successfully.")
# Out:
# Retriever created successfully.

# %%
question = "Who killed Harry's parents?"

retrieved_docs = retriever.invoke(question)

print("Number of retrieved documents:", len(retrieved_docs))

for i, doc in enumerate(retrieved_docs):

    print("\n" + "=" * 80)
    print(f"RETRIEVED DOCUMENT {i + 1}")
    print("=" * 80)

    print(doc.page_content)

    print("\nMetadata:")
    print(doc.metadata)
# Out:
# Number of retrieved documents: 4
#
# ================================================================================
# RETRIEVED DOCUMENT 1
# ================================================================================
# When Harry was just one year old, Lord Voldemort attacked the Potter family in Godric's Hollow. Lord Voldemort killed Harry's parents, James and Lily Potter. However, when Voldemort attempted to cast the Killing Curse (Avada Kedavra) on baby Harry, Lily's sacrificial protection caused the curse to rebound, destroying Voldemort's physical form and leaving Harry with a distinctive lightning bolt-shaped scar on his forehead.
#
# Metadata:
# {'source': 'HarryPotterRag.txt'}
#
# ================================================================================
# RETRIEVED DOCUMENT 2
# ================================================================================
# Harry James Potter is a wizard and the central figure in the fight against the dark wizard Lord Voldemort. Harry was born on July 31, 1980, to James Potter and Lily Potter (née Evans).
#
# Metadata:
# {'source': 'HarryPotterRag.txt'}
#
# ================================================================================
# RETRIEVED DOCUMENT 3
# ================================================================================
# Albus Dumbledore, the Headmaster of Hogwarts, served as an important mentor and protector for Harry throughout his school years. Dumbledore guided Harry in uncovering the secret of Voldemort's Horcruxes—magical objects containing pieces of Voldemort's soul—which needed to be destroyed to defeat him once and for all.
#
# Metadata:
# {'source': 'HarryPotterRag.txt'}
#
# ================================================================================
# RETRIEVED DOCUMENT 4
# ================================================================================
# Harry grew up unaware of his magical heritage with his non-magical relatives, the Dursleys: his Aunt Petunia, Uncle Vernon, and cousin Dudley. On his eleventh birthday, Rubeus Hagrid delivered Harry's acceptance letter to Hogwarts School of Witchcraft and Wizardry.
#
# At Hogwarts, Harry was sorted into Gryffindor house. He quickly became close friends with Ron Weasley and Hermione Granger. Harry proved to be a skilled Quidditch player, playing as the Seeker for the Gryffindor house team.
#
# Metadata:
# {'source': 'HarryPotterRag.txt'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash",
    temperature=0.5
)

print("LLM created successfully.")
# Out:
# LLM created successfully.

# %%
from langchain_core.prompts import ChatPromptTemplate

template = """
Answer the question based only on the following context:

{context}

Question:
{question}

Helpful Answer:
"""

prompt = ChatPromptTemplate.from_template(template)

print("Prompt created successfully.")
# Out:
# Prompt created successfully.

# %%
def format_docs(docs):

    return "\n\n".join(
        doc.page_content
        for doc in docs
    )

print("Document formatting function created successfully.")
# Out:
# Document formatting function created successfully.

# %%
question = "Who killed Harry's parents?"

context = format_docs(retrieved_docs)

formatted_prompt = prompt.invoke({
    "context": context,
    "question": question
})

print(formatted_prompt)
# Out:
# messages=[HumanMessage(content="\nAnswer the question based only on the following context:\n\nWhen Harry was just one year old, Lord Voldemort attacked the Potter family in Godric's Hollow. Lord Voldemort killed Harry's parents, James and Lily Potter. However, when Voldemort attempted to cast the Killing Curse (Avada Kedavra) on baby Harry, Lily's sacrificial protection caused the curse to rebound, destroying Voldemort's physical form and leaving Harry with a distinctive lightning bolt-shaped scar on his forehead.\n\nHarry James Potter is a wizard and the central figure in the fight against the dark wizard Lord Voldemort. Harry was born on July 31, 1980, to James Potter and Lily Potter (née Evans).\n\nAlbus Dumbledore, the Headmaster of Hogwarts, served as an important mentor and protector for Harry throughout his school years. Dumbledore guided Harry in uncovering the secret of Voldemort's Horcruxes—magical objects containing pieces of Voldemort's soul—which needed to be destroyed to defeat him once and for all.\n\nHarry grew up unaware of his magical heritage with his non-magical relatives, the Dursleys: his Aunt Petunia, Uncle Vernon, and cousin Dudley. On his eleventh birthday, Rubeus Hagrid delivered Harry's acceptance letter to Hogwarts School of Witchcraft and Wizardry.\n\nAt Hogwarts, Harry was sorted into Gryffindor house. He quickly became close friends with Ron Weasley and Hermione Granger. Harry proved to be a skilled Quidditch player, playing as the Seeker for the Gryffindor house team.\n\nQuestion:\nWho killed Harry's parents?\n\nHelpful Answer:\n", additional_kwargs={}, response_metadata={})]

# %%
response = llm.invoke(formatted_prompt)

print(response.content)
# Out:
# [{'type': 'text', 'text': "Based on the provided context, Lord Voldemort killed Harry's parents.", 'extras': {'signature': '...'}}]

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

rag_chain = (
    {
        "context": retriever | format_docs,
        "question": RunnablePassthrough()
    }
    | prompt
    | llm
    | StrOutputParser()
)

print("RAG chain created successfully.")
# Out:
# RAG chain created successfully.

# %%
message = input("Ask question: ")

output = rag_chain.invoke(message)

print("\nHelpful Answer:")
print(output)
# Out:
# Ask question:  Who killed Harry's parents?
# Helpful Answer:
# Helpful Answer:
# Lord Voldemort killed Harry's parents.

# %%
message = input("Ask question: ")

output = rag_chain.invoke(message)

print("\nAnswer:")
print(output)
# Out:
# Ask question:  Who are Harry's closest friends?
# Answer:
# Based on the provided context, Harry's closest friends are Ron Weasley and Hermione Granger.

# %%
message = input("Ask question: ")

output = rag_chain.invoke(message)

print("\nAnswer:")
print(output)
# Out:
# Ask question:  Who was Harry's mentor at Hogwarts?
# Answer:
# Helpful Answer: Albus Dumbledore, the Headmaster of Hogwarts.

# %%
message = input("Ask question: ")

output = rag_chain.invoke(message)

print("\nAnswer:")
print(output)
# Out:
# Ask question:  What is the capital of India?
# Answer:
# Based on the provided context, there is no mention of India or its capital.

# %%
import gradio as gr

print("Gradio version:", gr.__version__)
# Out:
# Gradio version: 6.24.0

# %%
def respond(message, history):

    response = rag_chain.invoke(message)

    return response

# %%
test_response = respond(
    "Who killed Harry's parents?",
    []
)

print(test_response)
# Out:
# Based on the provided context, Lord Voldemort killed Harry's parents.

# %%
demo = gr.ChatInterface(
    fn=respond,
    textbox=gr.Textbox(
        placeholder="Ask a question regarding Harry Potter..."
    ),
    title="Harry Potter RAG Document Reader",
    description="Ask questions based on the Harry Potter document."
)

print("Gradio interface created successfully.")
# Out:
# Gradio interface created successfully.

# %%
demo.launch(
    share=True,
    debug=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 demo.launch(
#       2     share=True,
#       3     debug=True
#       4 )
#
# NameError: name 'demo' is not defined

# %%
demo.close()
# Out:
# Closing server running on port: 7860
